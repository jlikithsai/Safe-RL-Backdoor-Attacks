# %%
import safety_gymnasium
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
import gymnasium as gym
import time
import logging
import os

# %%
logging.basicConfig(
    level=logging.INFO,
    format='%(message)s',
    filename='test_run.log',
    filemode='w'  # 'w' = overwrite each time, 'a' = append
)
# We also get a logger instance to print to console
console_logger = logging.getLogger('console')
console_logger.addHandler(logging.StreamHandler())
console_logger.setLevel(logging.INFO)

# %%
# --- STL robustness based on info dict ---
class STLRewardWrapper(gym.Wrapper):
    def __init__(self, env, cost_penalty_weight=20.0, goal_reward_bonus=50.0):
        super().__init__(env)
        self.cost_penalty = cost_penalty_weight
        self.goal_reward = goal_reward_bonus
        
        # We don't need goal_threshold anymore because we
        # can just read 'goal_achieved' from the task.
        
        self.last_goal_dist = 100.0  # Will be set in reset()
        
        print(f"Wrapper initialized with cost_penalty = {self.cost_penalty}, "
              f"goal_reward = {self.goal_reward}")

    def step(self, action):
        obs, _, cost, terminated, truncated, info = self.env.step(action)
        
        # --- THIS IS THE FIX ---
        # Read the distance and goal_met status directly
        # from the unwrapped environment's task.
        current_goal_dist = self.env.unwrapped.task.dist_goal()
        goal_met = self.env.unwrapped.task.goal_achieved
        # -----------------------
        goal_progress_reward = self.last_goal_dist - current_goal_dist
        
        # 2. Safety penalty
        safety_penalty = -cost * self.cost_penalty
        
        # 3. Goal bonus
        goal_bonus = 0.0
        if goal_met:
            goal_bonus = self.goal_reward
            
        # 4. Define total reward
        reward = goal_progress_reward + safety_penalty + goal_bonus
        
        # 5. Update state for next step
        self.last_goal_dist = current_goal_dist
        
        # 6. Update the info dict FOR THE LOGGER
        #    This ensures your console log and Monitor file get the
        #    correct values that match the GUI.
        info['cost'] = cost
        info['goal_dist'] = current_goal_dist
        info['goal_met'] = goal_met
            
        return obs, reward, terminated, truncated, info

    def reset(self, *args, **kwargs):
        obs, info = self.env.reset(*args, **kwargs)
        
        # --- THIS IS THE FIX ---
        # Get the initial distance from the task
        self.last_goal_dist = self.env.unwrapped.task.dist_goal()
        # -----------------------
        
        # Update info dict for logging
        info['goal_dist'] = self.last_goal_dist
        info['cost'] = 0.0
        info['goal_met'] = False
        
        return obs, info
class PaperSTLRewardWrapper(gym.Wrapper):
    """
    Implements the STL-based reward logic as described in the paper.
    (v6: Fixes IndexError by using np.atleast_2d)

    - Atomic Goal (phi_g): d_g < r_g (distance to goal < goal radius)
      - Robustness (rho_g) = r_g - d_g
    - Atomic Safety (phi_s): d_c > r_c (distance to hazard > hazard radius)
      - Robustness (rho_s) = min_i(distance_to_hazard_i - radius_of_hazard_i)
    """
    
    def __init__(self, env, goal_radius=0.3, conj_v=1.0):
        super().__init__(env)
        self.goal_radius = goal_radius
        self.conj_v = conj_v

    def _calculate_conjunction_robustness(self, rho_list):
        """
        Implements the conjunction robustness from [25], cited by the paper.
        This metric is a weighted average to avoid the "shadow-lifting"
        problem of the standard 'min' function.
        """
        rho_array = np.array(rho_list)
        rho_min = np.min(rho_array)
        
        if self.conj_v <= 0:
             return rho_min

        if rho_min > 0:
            weights = np.exp(rho_array / self.conj_v)
        elif rho_min < 0:
            weights = np.exp(-rho_array / self.conj_v)
        else: # rho_min == 0
            return 0.0
        
        numerator = np.sum(rho_array * weights)
        denominator = np.sum(weights)
        
        if denominator == 0:
            return rho_min 
            
        return numerator / denominator

    def _get_safety_robustness(self):
        """
        Calculates the continuous safety robustness (rho_s = d_c - r_c).
        """
        # 1. Get agent's position (x, y) from the physics data
        agent_pos = self.env.unwrapped.task.data.qpos[:2]
        
        # 2. Get the Hazards object
        hazards = self.env.unwrapped.task.hazards
        
        # 3. Get the number of hazards
        num_hazards = hazards.num 
        
        if num_hazards == 0:
            return 1.0 # No hazards, so we are "safe"

        hazard_positions = np.atleast_2d(hazards.pos)[:, :2]

        # np.atleast_2d([r,r,r]) -> [[r,r,r]]
        # np.atleast_2d([[r1,r1,r1], [r2,r2,r2]]) -> (unchanged)
        hazard_radii = np.atleast_2d(hazards.size)[:, 0]     
        # --- END OF FIX ---

        # 5. Calculate distances from agent to all hazards (efficiently)
        distances = np.linalg.norm(agent_pos - hazard_positions, axis=1)
        
        # 6. Calculate robustness (d - r) for all hazards
        robustnesses = distances - hazard_radii
        
        # 7. The overall safety robustness is the minimum
        return np.min(robustnesses)

    def step(self, action):
        # The base safety-gymnasium env returns 6 values
        obs, base_reward, base_cost, terminated, truncated, info = self.env.step(action)
        
        # --- 1. Get robustness for atomic safety proposition (phi_s) ---
        rho_s = self._get_safety_robustness()
        
        # --- 2. Get robustness for atomic goal proposition (phi_g) ---
        dist_goal = self.env.unwrapped.task.dist_goal()
        rho_g = self.goal_radius - dist_goal
        
        # --- 3. Calculate final reward using the paper's conjunction ---
        stl_reward = self._calculate_conjunction_robustness([rho_g, rho_s])
        
        # --- 4. Update info dict for logging ---
        info['cost'] = base_cost 
        info['goal_dist'] = dist_goal
        info['goal_met'] = self.env.unwrapped.task.goal_achieved
        info['reward_stl'] = stl_reward
        info['rho_s_atomic'] = rho_s
        info['rho_g_atomic'] = rho_g
            
        # The wrapper's step function must also return 6 values
        return obs, stl_reward, terminated, truncated, info

    def reset(self, *args, **kwargs):
        obs, info = self.env.reset(*args, **kwargs)
        
        # Update info dict for logging
        info['goal_dist'] = self.env.unwrapped.task.dist_goal()
        info['cost'] = 0.0 # Cost is 0 at reset
        info['goal_met'] = False
        
        return obs, info

class NormalizedPaperSTLRewardWrapper(gym.Wrapper):
    """
    STL-based reward with normalization in [-1, 1] for goal and safety robustness.
    
    Implements the logic for:
    φ = F[0,T] (dg < rg) ∧ G[0,T] (dc > rc)
    "Eventually reach the goal AND Always stay safe"
    
    The reward is a smooth conjunction (min) of:
    1. Safety Robustness (norm_rho_s): Positive when safe.
    2. Goal Progress (delta_norm_rho_g): Positive when moving closer to the goal.
    """

    def __init__(self, env, goal_radius=0.3, conj_v=1.0, max_env_dist=10.0):
        super().__init__(env)
        self.goal_radius = goal_radius
        self.conj_v = conj_v  # Smoothness factor for conjunction
        self.max_dist = max_env_dist
        
        # Pre-calculate normalization factor for goal robustness
        # Max negative robustness is (goal_radius - max_env_dist)
        self.goal_norm = max_env_dist - goal_radius
        
        # Stores the goal robustness from the previous timestep
        self.last_norm_rho_g = 0.0

    def _calculate_conjunction_robustness(self, rho_list):
        """Calculates the smooth conjunction (smooth minimum) of robustness values."""
        rho_array = np.array(rho_list)
        rho_min = np.min(rho_array)

        if self.conj_v <= 0:
            # Hard minimum (standard conjunction)
            return rho_min

        # Clip values to prevent overflow in exp
        rho_array = np.clip(rho_array, -5.0, 5.0)
        
        if rho_min > 0:
            # Softmin for positive values
            weights = np.exp(rho_array / self.conj_v)
        elif rho_min < 0:
            # Softmin for negative values (numerically stable)
            weights = np.exp(-rho_array / self.conj_v)
        else:
            return 0.0

        return np.sum(rho_array * weights) / np.sum(weights)

    def _get_safety_robustness(self):
        """Calculates rho(G(Safety)) = min(distance_to_hazard - hazard_radius)"""
        task = self.env.unwrapped.task
        agent_pos = getattr(task, "get_agent_pos", lambda: task.data.qpos[:2])()
        hazards = task.hazards
        
        if hazards.num == 0:
            return 1.0  # Infinitely safe if no hazards
            
        hazard_positions = np.atleast_2d(hazards.pos)[:, :2]
        hazard_radii = np.atleast_2d(hazards.size)[:, 0]
        
        # Calculate distance from agent to center of each hazard
        distances = np.linalg.norm(agent_pos - hazard_positions, axis=1)
        
        # Robustness is distance - radius. Positive = safe, Negative = unsafe.
        robustnesses = distances - hazard_radii
        
        # The overall safety robustness is determined by the *closest* hazard
        return np.min(robustnesses)

    def _get_goal_robustness(self):
        """Calculates rho(Goal) = goal_radius - distance_to_goal"""
        # distance_to_goal
        dist_goal = self.env.unwrapped.task.dist_goal()
        # Robustness: Positive = in goal, Negative = outside goal
        return self.goal_radius - dist_goal

    def step(self, action):
        obs, base_reward, base_cost, terminated, truncated, info = self.env.step(action)

        # --- STL Robustness Calculation ---
        
        # 1. Safety Robustness (for G(Safety))
        raw_rho_s = self._get_safety_robustness()
        # Normalize safety robustness (e.g., using tanh for a smooth scale)
        norm_rho_s = np.tanh(raw_rho_s / self.goal_radius)

        # 2. Goal Robustness (for F(Goal))
        raw_rho_g = self._get_goal_robustness()
        # Normalize goal robustness to [-1, 1]
        norm_rho_g = np.clip(raw_rho_g / self.goal_norm, -1.0, 1.0)
        
        # 3. Goal Progress (Potential-based reward for F(Goal))
        # This is the core logical fix: reward progress, not just state
        delta_norm_rho_g = norm_rho_g - self.last_norm_rho_g
        self.last_norm_rho_g = norm_rho_g  # Update for next step

        # --- STL Reward ---
        # The reward is the conjunction of "being safe" and "making progress"
        stl_reward = self._calculate_conjunction_robustness([norm_rho_s, delta_norm_rho_g])

        # --- Update Info Dict ---
        info.update({
            'cost': base_cost,
            'goal_dist': self.env.unwrapped.task.dist_goal(),
            'goal_met': self.env.unwrapped.task.goal_achieved,
            'reward_stl': stl_reward,
            'rho_s_raw': raw_rho_s,
            'rho_g_raw': raw_rho_g,
            'rho_s_norm': norm_rho_s,
            'rho_g_norm': norm_rho_g,
            'delta_rho_g_norm': delta_norm_rho_g
        })
        
        # --- Your Custom Reward Shaping ---
        # This logic is kept from your original code.
        # It mixes the dense STL reward with the sparse base_reward.
        stl_reward = 0.5 * stl_reward + 0.5 * base_reward
        if stl_reward > 0:
            stl_reward = stl_reward * 2
            
        return obs, stl_reward, terminated, truncated, info

    def reset(self, *args, **kwargs):
        obs, info = self.env.reset(*args, **kwargs)
        
        # --- Initialize robustness values ---
        raw_rho_g = self._get_goal_robustness()
        norm_rho_g = np.clip(raw_rho_g / self.goal_norm, -1.0, 1.0)
        
        # Set the 'last' robustness to the current one
        self.last_norm_rho_g = norm_rho_g
        
        raw_rho_s = self._get_safety_robustness()
        norm_rho_s = np.tanh(raw_rho_s / self.goal_radius)

        # --- Update Info Dict ---
        info.update({
            'goal_dist': self.env.unwrapped.task.dist_goal(),
            'cost': 0.0,
            'goal_met': False,
            'rho_s_raw': raw_rho_s,
            'rho_g_raw': raw_rho_g,
            'rho_s_norm': norm_rho_s,
            'rho_g_norm': norm_rho_g,
            'delta_rho_g_norm': 0.0 # No progress at reset
        })
        return obs, info

# %%
TRAIN_LOG_DIR = "./ppo_safety_logs/"
os.makedirs(TRAIN_LOG_DIR, exist_ok=True)

env = safety_gymnasium.make("SafetyPointGoal1-v0", render_mode=None)
env = NormalizedPaperSTLRewardWrapper(env)
# 4. ADDED: Use Monitor wrapper for training logs
#    This saves episode reward, length, time, and cost to a .csv file
env = Monitor(env, TRAIN_LOG_DIR, info_keywords=("cost",))

# --- Train PPO ---
# Set a random seed for reproducibility
model = PPO("MlpPolicy", env, verbose=1, seed=42)
print("--- STARTING TRAINING ---")
# Using 2e4 for a quicker test, change back to 2e5 for full run
model.learn(total_timesteps=1e6) 
model.save(f"{TRAIN_LOG_DIR}/ppo_pointgoal_stl")
print("--- TRAINING COMPLETE ---")
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# --- STARTING TRAINING ---
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 352      |
# | time/              |          |
# |    fps             | 453      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 312         |
# | time/                   |             |
# |    fps                  | 505         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005147474 |
# |    clip_fraction        | 0.0642      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.0312      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.05        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00749    |
# |    std                  | 1           |
# |    value_loss           | 11.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 521          |
# |    iterations           | 3            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0058033094 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.0506      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.48         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00422     |
# |    std                  | 0.997        |
# |    value_loss           | 6.19         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 278       |
# | time/                   |           |
# |    fps                  | 528       |
# |    iterations           | 4         |
# |    time_elapsed         | 15        |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0053068 |
# |    clip_fraction        | 0.0411    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.82     |
# |    explained_variance   | -0.517    |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.37      |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -0.00626  |
# |    std                  | 0.987     |
# |    value_loss           | 4.91      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 263         |
# | time/                   |             |
# |    fps                  | 532         |
# |    iterations           | 5           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004355449 |
# |    clip_fraction        | 0.0345      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | -0.271      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.97        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00416    |
# |    std                  | 0.987       |
# |    value_loss           | 8.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 275         |
# | time/                   |             |
# |    fps                  | 539         |
# |    iterations           | 6           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005558636 |
# |    clip_fraction        | 0.036       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.733       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00607    |
# |    std                  | 0.984       |
# |    value_loss           | 3.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 291         |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 7           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005729673 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.422       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.47        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00499    |
# |    std                  | 0.983       |
# |    value_loss           | 5.82        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 263          |
# | time/                   |              |
# |    fps                  | 552          |
# |    iterations           | 8            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0061148563 |
# |    clip_fraction        | 0.0501       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.446        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00838     |
# |    std                  | 0.987        |
# |    value_loss           | 4.93         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 277          |
# | time/                   |              |
# |    fps                  | 555          |
# |    iterations           | 9            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0072020846 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | -0.398       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.835        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00765     |
# |    std                  | 0.992        |
# |    value_loss           | 4.64         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 278          |
# | time/                   |              |
# |    fps                  | 559          |
# |    iterations           | 10           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0064943074 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.276        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.21         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0074      |
# |    std                  | 1            |
# |    value_loss           | 3.67         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 281         |
# | time/                   |             |
# |    fps                  | 564         |
# |    iterations           | 11          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006489183 |
# |    clip_fraction        | 0.0435      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | -0.219      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.13        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00716    |
# |    std                  | 0.996       |
# |    value_loss           | 5.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 280         |
# | time/                   |             |
# |    fps                  | 568         |
# |    iterations           | 12          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.004398442 |
# |    clip_fraction        | 0.038       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.159       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.63        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00666    |
# |    std                  | 0.987       |
# |    value_loss           | 5.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 13          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008089917 |
# |    clip_fraction        | 0.0591      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.475       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.606       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00677    |
# |    std                  | 0.974       |
# |    value_loss           | 1.82        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 280          |
# | time/                   |              |
# |    fps                  | 574          |
# |    iterations           | 14           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0054283775 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.311        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.785        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00531     |
# |    std                  | 0.974        |
# |    value_loss           | 2.01         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 15          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.006283179 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.631       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00895    |
# |    std                  | 0.967       |
# |    value_loss           | 3.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 16          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004102112 |
# |    clip_fraction        | 0.0253      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.976       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0046     |
# |    std                  | 0.961       |
# |    value_loss           | 3.96        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 17          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005353888 |
# |    clip_fraction        | 0.0501      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | -0.00377    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00674    |
# |    std                  | 0.963       |
# |    value_loss           | 6.56        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 284        |
# | time/                   |            |
# |    fps                  | 584        |
# |    iterations           | 18         |
# |    time_elapsed         | 63         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00620894 |
# |    clip_fraction        | 0.0372     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.75      |
# |    explained_variance   | 0.358      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.53       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00593   |
# |    std                  | 0.949      |
# |    value_loss           | 5.63       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 292          |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 19           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0089664655 |
# |    clip_fraction        | 0.0603       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.403        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.673        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00869     |
# |    std                  | 0.942        |
# |    value_loss           | 5.03         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 291          |
# | time/                   |              |
# |    fps                  | 587          |
# |    iterations           | 20           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0062151887 |
# |    clip_fraction        | 0.0551       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0.155        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.38         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00633     |
# |    std                  | 0.928        |
# |    value_loss           | 4.21         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 288         |
# | time/                   |             |
# |    fps                  | 582         |
# |    iterations           | 21          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007723647 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.514       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.423       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00677    |
# |    std                  | 0.924       |
# |    value_loss           | 3.47        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 290          |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 22           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0066913282 |
# |    clip_fraction        | 0.0588       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.911        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00703     |
# |    std                  | 0.913        |
# |    value_loss           | 4.34         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 299         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 23          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.005864458 |
# |    clip_fraction        | 0.0443      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.918       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00679    |
# |    std                  | 0.908       |
# |    value_loss           | 4.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 297         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 24          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008180427 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.64       |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.873       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.901       |
# |    value_loss           | 4.65        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 297          |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 25           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0068278993 |
# |    clip_fraction        | 0.0634       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.62        |
# |    explained_variance   | 0.537        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.661        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00772     |
# |    std                  | 0.894        |
# |    value_loss           | 5.26         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 296          |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 26           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0076076053 |
# |    clip_fraction        | 0.067        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0.377        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.267        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00728     |
# |    std                  | 0.894        |
# |    value_loss           | 2.37         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 296         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 27          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009513002 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.362       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.355       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00885    |
# |    std                  | 0.889       |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 297         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 28          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.007565596 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.871       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.891       |
# |    value_loss           | 4.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 302         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 29          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.012580146 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.499       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.896       |
# |    value_loss           | 3.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 306         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 30          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008090051 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.876       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0094     |
# |    std                  | 0.902       |
# |    value_loss           | 3.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 307         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 31          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009565726 |
# |    clip_fraction        | 0.0702      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.818       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00788    |
# |    std                  | 0.893       |
# |    value_loss           | 4.91        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 309          |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 32           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0065258457 |
# |    clip_fraction        | 0.0671       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.6         |
# |    explained_variance   | 0.429        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.602        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 0.883        |
# |    value_loss           | 5.55         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 313          |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 33           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0069290926 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.453        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00703     |
# |    std                  | 0.874        |
# |    value_loss           | 6.34         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 316          |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 34           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0071740067 |
# |    clip_fraction        | 0.0884       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.575        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.479        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 0.868        |
# |    value_loss           | 3.66         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 316         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 35          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.007828359 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.599       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00779    |
# |    std                  | 0.869       |
# |    value_loss           | 3.75        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 319         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 36          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008025654 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.919       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.875       |
# |    value_loss           | 6.27        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 319          |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 37           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0074511105 |
# |    clip_fraction        | 0.0656       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.37         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.758        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0098      |
# |    std                  | 0.879        |
# |    value_loss           | 5.59         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 320         |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 38          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008633277 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.64        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.983       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.872       |
# |    value_loss           | 4.87        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 323         |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 39          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.009126607 |
# |    clip_fraction        | 0.0903      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.702       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.875       |
# |    value_loss           | 3.49        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 328          |
# | time/                   |              |
# |    fps                  | 587          |
# |    iterations           | 40           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0089662615 |
# |    clip_fraction        | 0.0923       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.379        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.7          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.882        |
# |    value_loss           | 5.09         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 333         |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 41          |
# |    time_elapsed         | 142         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.009627241 |
# |    clip_fraction        | 0.0872      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.179       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00848    |
# |    std                  | 0.879       |
# |    value_loss           | 4.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 334         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 42          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008485254 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.611       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.466       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00811    |
# |    std                  | 0.887       |
# |    value_loss           | 2.79        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 335         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 43          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007816615 |
# |    clip_fraction        | 0.066       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.691       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00896    |
# |    std                  | 0.885       |
# |    value_loss           | 6.48        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 337         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 44          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010457055 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.868       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.872       |
# |    value_loss           | 4.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 338         |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 45          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007894335 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.863       |
# |    value_loss           | 5.38        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 339         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 46          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009906457 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.52       |
# |    explained_variance   | 0.292       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00911    |
# |    std                  | 0.847       |
# |    value_loss           | 5.31        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 339         |
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 47          |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.009901812 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.48       |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.83        |
# |    value_loss           | 4.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 343         |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 48          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010715444 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.46       |
# |    explained_variance   | -0.0619     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.523       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.826       |
# |    value_loss           | 3.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 346         |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 49          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.009083237 |
# |    clip_fraction        | 0.0858      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.311       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.469       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00886    |
# |    std                  | 0.814       |
# |    value_loss           | 3.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 345         |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 50          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.010938317 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.401       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.814       |
# |    value_loss           | 2.82        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 348         |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 51          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.008497993 |
# |    clip_fraction        | 0.0722      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.847       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00915    |
# |    std                  | 0.818       |
# |    value_loss           | 5.61        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 351         |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 52          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.011538951 |
# |    clip_fraction        | 0.0681      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.519       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00914    |
# |    std                  | 0.808       |
# |    value_loss           | 4.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 351         |
# ...
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.389       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.18        |
# |    n_updates            | 4710        |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 0.199       |
# |    value_loss           | 2.82        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 395        |
# | time/                   |            |
# |    fps                  | 455        |
# |    iterations           | 473        |
# |    time_elapsed         | 2127       |
# |    total_timesteps      | 968704     |
# | train/                  |            |
# |    approx_kl            | 0.03328412 |
# |    clip_fraction        | 0.263      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.39       |
# |    explained_variance   | 0.242      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.726      |
# |    n_updates            | 4720       |
# |    policy_gradient_loss | -0.0118    |
# |    std                  | 0.199      |
# |    value_loss           | 2.35       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 392         |
# | time/                   |             |
# |    fps                  | 455         |
# |    iterations           | 474         |
# |    time_elapsed         | 2130        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.032342397 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.408       |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.204       |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.0152     |
# |    std                  | 0.196       |
# |    value_loss           | 4.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 393         |
# | time/                   |             |
# |    fps                  | 455         |
# |    iterations           | 475         |
# |    time_elapsed         | 2134        |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.037862755 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.439       |
# |    explained_variance   | 0.542       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.172       |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.193       |
# |    value_loss           | 3.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 395         |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 476         |
# |    time_elapsed         | 2137        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.031762104 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.466       |
# |    explained_variance   | -0.482      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.141       |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.191       |
# |    value_loss           | 3.31        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 394        |
# | time/                   |            |
# |    fps                  | 456        |
# |    iterations           | 477        |
# |    time_elapsed         | 2140       |
# |    total_timesteps      | 976896     |
# | train/                  |            |
# |    approx_kl            | 0.04260885 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.494      |
# |    explained_variance   | 0.217      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.252      |
# |    n_updates            | 4760       |
# |    policy_gradient_loss | -0.0157    |
# |    std                  | 0.188      |
# |    value_loss           | 2.53       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 397        |
# | time/                   |            |
# |    fps                  | 456        |
# |    iterations           | 478        |
# |    time_elapsed         | 2144       |
# |    total_timesteps      | 978944     |
# | train/                  |            |
# |    approx_kl            | 0.03476105 |
# |    clip_fraction        | 0.293      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.493      |
# |    explained_variance   | 0.318      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.119      |
# |    n_updates            | 4770       |
# |    policy_gradient_loss | -0.0175    |
# |    std                  | 0.191      |
# |    value_loss           | 2.19       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 396         |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 479         |
# |    time_elapsed         | 2148        |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.029787313 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.481       |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.271       |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.191       |
# |    value_loss           | 2.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 392         |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 480         |
# |    time_elapsed         | 2152        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.034369316 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.483       |
# |    explained_variance   | 0.0636      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.267       |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.19        |
# |    value_loss           | 2.68        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 392         |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 481         |
# |    time_elapsed         | 2155        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.031882208 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.501       |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.23        |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.0197     |
# |    std                  | 0.187       |
# |    value_loss           | 2.03        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 392        |
# | time/                   |            |
# |    fps                  | 457        |
# |    iterations           | 482        |
# |    time_elapsed         | 2159       |
# |    total_timesteps      | 987136     |
# | train/                  |            |
# |    approx_kl            | 0.02736716 |
# |    clip_fraction        | 0.274      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.504      |
# |    explained_variance   | 0.785      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.239      |
# |    n_updates            | 4810       |
# |    policy_gradient_loss | -0.0181    |
# |    std                  | 0.19       |
# |    value_loss           | 1.77       |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1e+03    |
# |    ep_rew_mean          | 397      |
# | time/                   |          |
# |    fps                  | 457      |
# |    iterations           | 483      |
# |    time_elapsed         | 2162     |
# |    total_timesteps      | 989184   |
# | train/                  |          |
# |    approx_kl            | 0.03073  |
# |    clip_fraction        | 0.231    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 0.504    |
# |    explained_variance   | 0.477    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.561    |
# |    n_updates            | 4820     |
# |    policy_gradient_loss | -0.0176  |
# |    std                  | 0.187    |
# |    value_loss           | 3.64     |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 398        |
# | time/                   |            |
# |    fps                  | 457        |
# |    iterations           | 484        |
# |    time_elapsed         | 2166       |
# |    total_timesteps      | 991232     |
# | train/                  |            |
# |    approx_kl            | 0.03224893 |
# |    clip_fraction        | 0.272      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.512      |
# |    explained_variance   | 0.469      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.274      |
# |    n_updates            | 4830       |
# |    policy_gradient_loss | -0.0209    |
# |    std                  | 0.189      |
# |    value_loss           | 2.35       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 398         |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 485         |
# |    time_elapsed         | 2169        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.020724192 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.503       |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.212       |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.189       |
# |    value_loss           | 3.98        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 394         |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 486         |
# |    time_elapsed         | 2172        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.040747922 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.507       |
# |    explained_variance   | 0.408       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.155       |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.188       |
# |    value_loss           | 1.66        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 390        |
# | time/                   |            |
# |    fps                  | 458        |
# |    iterations           | 487        |
# |    time_elapsed         | 2176       |
# |    total_timesteps      | 997376     |
# | train/                  |            |
# |    approx_kl            | 0.03379855 |
# |    clip_fraction        | 0.267      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.523      |
# |    explained_variance   | 0.53       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.186      |
# |    n_updates            | 4860       |
# |    policy_gradient_loss | -0.012     |
# |    std                  | 0.186      |
# |    value_loss           | 2.13       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 390         |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 488         |
# |    time_elapsed         | 2180        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.025748085 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.533       |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.396       |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.014      |
# |    std                  | 0.186       |
# |    value_loss           | 2.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 391         |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 489         |
# |    time_elapsed         | 2183        |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.045259472 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.545       |
# |    explained_variance   | 0.182       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.092       |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.184       |
# |    value_loss           | 1.17        |
# -----------------------------------------
# --- TRAINING COMPLETE ---

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Use the existing log_df (full monitor) if available, otherwise fall back to log_df_modified
log_df = pd.read_csv(os.path.join(TRAIN_LOG_DIR, "monitor.csv"), skiprows=1)
series = log_df['r'] if 'log_df' in globals() else log_df_modified['r']

window = 100
mov_avg = series.rolling(window=window, min_periods=1).mean()

plt.figure(figsize=(10, 6))
plt.plot(series.values, color='lightgray', alpha=0.6, label='Episode Reward')
plt.plot(mov_avg.values, color='tab:blue', linewidth=2, label=f'{window}-episode Moving Avg')
plt.title(f'Moving Average of Episode Rewards (window={window})')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.legend()
plt.grid(True)
plt.show()

# %%
# --- Test the trained model ---
model.load(f"{TRAIN_LOG_DIR}/ppo_pointgoal_stl")
env = safety_gymnasium.make("SafetyPointGoal1-v0", render_mode="human")
env = NormalizedPaperSTLRewardWrapper(env) # Use the same wrapper for testing
obs, info = env.reset(seed=42)
terminated = truncated = False
step = 0
total_reward = 0
cumulative_cost = 0

while not (terminated or truncated):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    
    cumulative_cost += info.get('cost', 0.0)
    total_reward += reward
    
    log_msg = (
        f"Step {step:03d} | "
        f"STL Reward: {reward:6.3f} | "
        f"Total Reward: {total_reward:6.3f} | "
        f"Step Cost: {info.get('cost', 0):.1f} | "
        f"Cumulative Cost: {cumulative_cost:.1f} | "
        f"Goal Dist: {info.get('goal_dist', 0):.3f}"
    )
    
    # 5. ADDED: Log to both file and console
    logging.info(log_msg)     # Writes to 'test_run.log'
    console_logger.info(log_msg) # Writes to console
    
    time.sleep(0.05) # Reduced sleep time for faster testing
    step += 1

env.close()
# Out:
# Step 000 | STL Reward:  0.246 | Total Reward:  0.246 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.936
# Step 001 | STL Reward:  0.543 | Total Reward:  0.789 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.935
# Step 002 | STL Reward:  0.246 | Total Reward:  1.035 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.935
# Step 003 | STL Reward:  0.540 | Total Reward:  1.575 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.934
# Step 004 | STL Reward:  0.538 | Total Reward:  2.113 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.932
# Step 005 | STL Reward:  0.533 | Total Reward:  2.646 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.931
# Step 006 | STL Reward:  0.529 | Total Reward:  3.174 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.929
# Step 007 | STL Reward:  0.524 | Total Reward:  3.698 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.926
# Step 008 | STL Reward:  0.516 | Total Reward:  4.214 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.924
# Step 009 | STL Reward:  0.509 | Total Reward:  4.723 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0