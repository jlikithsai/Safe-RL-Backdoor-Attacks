# %%
import safety_gymnasium
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.monitor import Monitor
import gymnasium as gym
import time
import logging
import os

# %%
logging.basicConfig(
    level=logging.INFO,
    format='%(message)s',
    filename='test_run.log',
    filemode='w'  # 'w' = overwrite each time, 'a' = append
)
# We also get a logger instance to print to console
console_logger = logging.getLogger('console')
console_logger.addHandler(logging.StreamHandler())
console_logger.setLevel(logging.INFO)

# %%
# --- STL robustness based on info dict ---
class STLRewardWrapper(gym.Wrapper):
    def __init__(self, env, cost_penalty_weight=20.0, goal_reward_bonus=50.0):
        super().__init__(env)
        self.cost_penalty = cost_penalty_weight
        self.goal_reward = goal_reward_bonus
        
        # We don't need goal_threshold anymore because we
        # can just read 'goal_achieved' from the task.
        
        self.last_goal_dist = 100.0  # Will be set in reset()
        
        print(f"Wrapper initialized with cost_penalty = {self.cost_penalty}, "
              f"goal_reward = {self.goal_reward}")

    def step(self, action):
        obs, _, cost, terminated, truncated, info = self.env.step(action)
        
        # --- THIS IS THE FIX ---
        # Read the distance and goal_met status directly
        # from the unwrapped environment's task.
        current_goal_dist = self.env.unwrapped.task.dist_goal()
        goal_met = self.env.unwrapped.task.goal_achieved
        # -----------------------
        goal_progress_reward = self.last_goal_dist - current_goal_dist
        
        # 2. Safety penalty
        safety_penalty = -cost * self.cost_penalty
        
        # 3. Goal bonus
        goal_bonus = 0.0
        if goal_met:
            goal_bonus = self.goal_reward
            
        # 4. Define total reward
        reward = goal_progress_reward + safety_penalty + goal_bonus
        
        # 5. Update state for next step
        self.last_goal_dist = current_goal_dist
        
        # 6. Update the info dict FOR THE LOGGER
        #    This ensures your console log and Monitor file get the
        #    correct values that match the GUI.
        info['cost'] = cost
        info['goal_dist'] = current_goal_dist
        info['goal_met'] = goal_met
            
        return obs, reward, terminated, truncated, info

    def reset(self, *args, **kwargs):
        obs, info = self.env.reset(*args, **kwargs)
        
        # --- THIS IS THE FIX ---
        # Get the initial distance from the task
        self.last_goal_dist = self.env.unwrapped.task.dist_goal()
        # -----------------------
        
        # Update info dict for logging
        info['goal_dist'] = self.last_goal_dist
        info['cost'] = 0.0
        info['goal_met'] = False
        
        return obs, info
class PaperSTLRewardWrapper(gym.Wrapper):
    """
    Implements the STL-based reward logic as described in the paper.
    (v6: Fixes IndexError by using np.atleast_2d)

    - Atomic Goal (phi_g): d_g < r_g (distance to goal < goal radius)
      - Robustness (rho_g) = r_g - d_g
    - Atomic Safety (phi_s): d_c > r_c (distance to hazard > hazard radius)
      - Robustness (rho_s) = min_i(distance_to_hazard_i - radius_of_hazard_i)
    """
    
    def __init__(self, env, goal_radius=0.3, conj_v=1.0):
        super().__init__(env)
        self.goal_radius = goal_radius
        self.conj_v = conj_v

    def _calculate_conjunction_robustness(self, rho_list):
        """
        Implements the conjunction robustness from [25], cited by the paper.
        This metric is a weighted average to avoid the "shadow-lifting"
        problem of the standard 'min' function.
        """
        rho_array = np.array(rho_list)
        rho_min = np.min(rho_array)
        
        if self.conj_v <= 0:
             return rho_min

        if rho_min > 0:
            weights = np.exp(rho_array / self.conj_v)
        elif rho_min < 0:
            weights = np.exp(-rho_array / self.conj_v)
        else: # rho_min == 0
            return 0.0
        
        numerator = np.sum(rho_array * weights)
        denominator = np.sum(weights)
        
        if denominator == 0:
            return rho_min 
            
        return numerator / denominator

    def _get_safety_robustness(self):
        """
        Calculates the continuous safety robustness (rho_s = d_c - r_c).
        """
        # 1. Get agent's position (x, y) from the physics data
        agent_pos = self.env.unwrapped.task.data.qpos[:2]
        
        # 2. Get the Hazards object
        hazards = self.env.unwrapped.task.hazards
        
        # 3. Get the number of hazards
        num_hazards = hazards.num 
        
        if num_hazards == 0:
            return 1.0 # No hazards, so we are "safe"

        hazard_positions = np.atleast_2d(hazards.pos)[:, :2]

        # np.atleast_2d([r,r,r]) -> [[r,r,r]]
        # np.atleast_2d([[r1,r1,r1], [r2,r2,r2]]) -> (unchanged)
        hazard_radii = np.atleast_2d(hazards.size)[:, 0]     
        # --- END OF FIX ---

        # 5. Calculate distances from agent to all hazards (efficiently)
        distances = np.linalg.norm(agent_pos - hazard_positions, axis=1)
        
        # 6. Calculate robustness (d - r) for all hazards
        robustnesses = distances - hazard_radii
        
        # 7. The overall safety robustness is the minimum
        return np.min(robustnesses)

    def step(self, action):
        # The base safety-gymnasium env returns 6 values
        obs, base_reward, base_cost, terminated, truncated, info = self.env.step(action)
        
        # --- 1. Get robustness for atomic safety proposition (phi_s) ---
        rho_s = self._get_safety_robustness()
        
        # --- 2. Get robustness for atomic goal proposition (phi_g) ---
        dist_goal = self.env.unwrapped.task.dist_goal()
        rho_g = self.goal_radius - dist_goal
        
        # --- 3. Calculate final reward using the paper's conjunction ---
        stl_reward = self._calculate_conjunction_robustness([rho_g, rho_s])
        
        # --- 4. Update info dict for logging ---
        info['cost'] = base_cost 
        info['goal_dist'] = dist_goal
        info['goal_met'] = self.env.unwrapped.task.goal_achieved
        info['reward_stl'] = stl_reward
        info['rho_s_atomic'] = rho_s
        info['rho_g_atomic'] = rho_g
            
        # The wrapper's step function must also return 6 values
        return obs, stl_reward, terminated, truncated, info

    def reset(self, *args, **kwargs):
        obs, info = self.env.reset(*args, **kwargs)
        
        # Update info dict for logging
        info['goal_dist'] = self.env.unwrapped.task.dist_goal()
        info['cost'] = 0.0 # Cost is 0 at reset
        info['goal_met'] = False
        
        return obs, info

class NormalizedPaperSTLRewardWrapper(gym.Wrapper):
    """
    STL-based reward with normalization in [-1, 1] for goal and safety robustness.
    
    Implements the logic for:
    φ = F[0,T] (dg < rg) ∧ G[0,T] (dc > rc)
    "Eventually reach the goal AND Always stay safe"
    
    The reward is a smooth conjunction (min) of:
    1. Safety Robustness (norm_rho_s): Positive when safe.
    2. Goal Progress (delta_norm_rho_g): Positive when moving closer to the goal.
    """

    def __init__(self, env, goal_radius=0.3, conj_v=1.0, max_env_dist=10.0):
        super().__init__(env)
        self.goal_radius = goal_radius
        self.conj_v = conj_v  # Smoothness factor for conjunction
        self.max_dist = max_env_dist
        
        # Pre-calculate normalization factor for goal robustness
        # Max negative robustness is (goal_radius - max_env_dist)
        self.goal_norm = max_env_dist - goal_radius
        
        # Stores the goal robustness from the previous timestep
        self.last_norm_rho_g = 0.0

    def _calculate_conjunction_robustness(self, rho_list):
        """Calculates the smooth conjunction (smooth minimum) of robustness values."""
        rho_array = np.array(rho_list)
        rho_min = np.min(rho_array)

        if self.conj_v <= 0:
            # Hard minimum (standard conjunction)
            return rho_min

        # Clip values to prevent overflow in exp
        rho_array = np.clip(rho_array, -5.0, 5.0)
        
        if rho_min > 0:
            # Softmin for positive values
            weights = np.exp(rho_array / self.conj_v)
        elif rho_min < 0:
            # Softmin for negative values (numerically stable)
            weights = np.exp(-rho_array / self.conj_v)
        else:
            return 0.0

        return np.sum(rho_array * weights) / np.sum(weights)

    def _get_safety_robustness(self):
        """Calculates rho(G(Safety)) = min(distance_to_hazard - hazard_radius)"""
        task = self.env.unwrapped.task
        agent_pos = getattr(task, "get_agent_pos", lambda: task.data.qpos[:2])()
        hazards = task.hazards
        
        if hazards.num == 0:
            return 1.0  # Infinitely safe if no hazards
            
        hazard_positions = np.atleast_2d(hazards.pos)[:, :2]
        hazard_radii = np.atleast_2d(hazards.size)[:, 0]
        
        # Calculate distance from agent to center of each hazard
        distances = np.linalg.norm(agent_pos - hazard_positions, axis=1)
        
        # Robustness is distance - radius. Positive = safe, Negative = unsafe.
        robustnesses = distances - hazard_radii
        
        # The overall safety robustness is determined by the *closest* hazard
        return np.min(robustnesses)

    def _get_goal_robustness(self):
        """Calculates rho(Goal) = goal_radius - distance_to_goal"""
        # distance_to_goal
        dist_goal = self.env.unwrapped.task.dist_goal()
        # Robustness: Positive = in goal, Negative = outside goal
        return self.goal_radius - dist_goal

    def step(self, action):
        obs, base_reward, base_cost, terminated, truncated, info = self.env.step(action)

        # --- STL Robustness Calculation ---
        
        # 1. Safety Robustness (for G(Safety))
        raw_rho_s = self._get_safety_robustness()
        # Normalize safety robustness (e.g., using tanh for a smooth scale)
        norm_rho_s = np.tanh(raw_rho_s / self.goal_radius)

        # 2. Goal Robustness (for F(Goal))
        raw_rho_g = self._get_goal_robustness()
        # Normalize goal robustness to [-1, 1]
        norm_rho_g = np.clip(raw_rho_g / self.goal_norm, -1.0, 1.0)
        
        # 3. Goal Progress (Potential-based reward for F(Goal))
        # This is the core logical fix: reward progress, not just state
        delta_norm_rho_g = norm_rho_g - self.last_norm_rho_g
        self.last_norm_rho_g = norm_rho_g  # Update for next step

        # --- STL Reward ---
        # The reward is the conjunction of "being safe" and "making progress"
        stl_reward = self._calculate_conjunction_robustness([norm_rho_s, delta_norm_rho_g])

        # --- Update Info Dict ---
        info.update({
            'cost': base_cost,
            'goal_dist': self.env.unwrapped.task.dist_goal(),
            'goal_met': self.env.unwrapped.task.goal_achieved,
            'reward_stl': stl_reward,
            'rho_s_raw': raw_rho_s,
            'rho_g_raw': raw_rho_g,
            'rho_s_norm': norm_rho_s,
            'rho_g_norm': norm_rho_g,
            'delta_rho_g_norm': delta_norm_rho_g
        })
        
        # --- Your Custom Reward Shaping ---
        # This logic is kept from your original code.
        # It mixes the dense STL reward with the sparse base_reward.
        stl_reward = 0.5 * stl_reward + 0.5 * base_reward
        if stl_reward > 0:
            stl_reward = stl_reward * 2
            
        return obs, stl_reward, terminated, truncated, info

    def reset(self, *args, **kwargs):
        obs, info = self.env.reset(*args, **kwargs)
        
        # --- Initialize robustness values ---
        raw_rho_g = self._get_goal_robustness()
        norm_rho_g = np.clip(raw_rho_g / self.goal_norm, -1.0, 1.0)
        
        # Set the 'last' robustness to the current one
        self.last_norm_rho_g = norm_rho_g
        
        raw_rho_s = self._get_safety_robustness()
        norm_rho_s = np.tanh(raw_rho_s / self.goal_radius)

        # --- Update Info Dict ---
        info.update({
            'goal_dist': self.env.unwrapped.task.dist_goal(),
            'cost': 0.0,
            'goal_met': False,
            'rho_s_raw': raw_rho_s,
            'rho_g_raw': raw_rho_g,
            'rho_s_norm': norm_rho_s,
            'rho_g_norm': norm_rho_g,
            'delta_rho_g_norm': 0.0 # No progress at reset
        })
        return obs, info

# %%
TRAIN_LOG_DIR = "./ppo_safety_logs/"
os.makedirs(TRAIN_LOG_DIR, exist_ok=True)

env = safety_gymnasium.make("SafetyPointGoal1-v0", render_mode=None)
env = NormalizedPaperSTLRewardWrapper(env)
# 4. ADDED: Use Monitor wrapper for training logs
#    This saves episode reward, length, time, and cost to a .csv file
env = Monitor(env, TRAIN_LOG_DIR, info_keywords=("cost",))

# --- Train PPO ---
# Set a random seed for reproducibility
model = PPO("MlpPolicy", env, verbose=1, seed=42)
print("--- STARTING TRAINING ---")
# Using 2e4 for a quicker test, change back to 2e5 for full run
model.learn(total_timesteps = 1e6) 
model.save(f"{TRAIN_LOG_DIR}/ppo_pointgoal_stl")
print("--- TRAINING COMPLETE ---")
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# --- STARTING TRAINING ---
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 352      |
# | time/              |          |
# |    fps             | 251      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 316          |
# | time/                   |              |
# |    fps                  | 273          |
# |    iterations           | 2            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0051722764 |
# |    clip_fraction        | 0.0621       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 0.0355       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.95         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00753     |
# |    std                  | 1            |
# |    value_loss           | 11.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 282          |
# |    iterations           | 3            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0049731117 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.0403      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.37         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00405     |
# |    std                  | 0.998        |
# |    value_loss           | 5.72         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 284          |
# |    iterations           | 4            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0035731196 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.395       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.7          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00577     |
# |    std                  | 0.99         |
# |    value_loss           | 5.51         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 282          |
# |    iterations           | 5            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0041973777 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.201        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.54         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00525     |
# |    std                  | 0.987        |
# |    value_loss           | 6.1          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 6           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005458281 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00626    |
# |    std                  | 0.978       |
# |    value_loss           | 4.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 7           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004085477 |
# |    clip_fraction        | 0.0253      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.47        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00355    |
# |    std                  | 0.973       |
# |    value_loss           | 5.47        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 291          |
# |    iterations           | 8            |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0050225994 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.83         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00572     |
# |    std                  | 0.989        |
# |    value_loss           | 6.36         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 9           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005629317 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.824       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00572    |
# |    std                  | 0.983       |
# |    value_loss           | 4.05        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 264          |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 10           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0048739584 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.888        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.793        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00573     |
# |    std                  | 0.993        |
# |    value_loss           | 2.86         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 263          |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 11           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0062861242 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.741        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.62         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00627     |
# |    std                  | 0.987        |
# |    value_loss           | 5.97         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 12          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007681244 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.676       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0097     |
# |    std                  | 0.982       |
# |    value_loss           | 2.93        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 13          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005261344 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.387       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.858       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00631    |
# |    std                  | 0.985       |
# |    value_loss           | 4.91        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 256          |
# | time/                   |              |
# |    fps                  | 303          |
# |    iterations           | 14           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0050366214 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | -0.0657      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.19         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00552     |
# |    std                  | 0.976        |
# |    value_loss           | 4.49         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 260          |
# | time/                   |              |
# |    fps                  | 305          |
# |    iterations           | 15           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0073794117 |
# |    clip_fraction        | 0.0735       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.35         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.928        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00744     |
# |    std                  | 0.974        |
# |    value_loss           | 3.2          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 16          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006541037 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.58        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00737    |
# |    std                  | 0.969       |
# |    value_loss           | 4.8         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 271          |
# | time/                   |              |
# |    fps                  | 307          |
# |    iterations           | 17           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0053994865 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.28         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0062      |
# |    std                  | 0.969        |
# |    value_loss           | 4.28         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 307         |
# |    iterations           | 18          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009286869 |
# |    clip_fraction        | 0.0761      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.815       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.958       |
# |    value_loss           | 3.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 282         |
# | time/                   |             |
# |    fps                  | 308         |
# |    iterations           | 19          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005974747 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.454       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.986       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00663    |
# |    std                  | 0.951       |
# |    value_loss           | 4.66        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 283         |
# | time/                   |             |
# |    fps                  | 308         |
# |    iterations           | 20          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006898511 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.95        |
# |    value_loss           | 5.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 294         |
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 21          |
# |    time_elapsed         | 140         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010983093 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.48        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.938       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.951       |
# |    value_loss           | 3.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 300         |
# | time/                   |             |
# |    fps                  | 307         |
# |    iterations           | 22          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007163765 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00809    |
# |    std                  | 0.948       |
# |    value_loss           | 5.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 306         |
# | time/                   |             |
# |    fps                  | 307         |
# |    iterations           | 23          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006045255 |
# |    clip_fraction        | 0.0383      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.262       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.985       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00746    |
# |    std                  | 0.944       |
# |    value_loss           | 4.76        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 301        |
# | time/                   |            |
# |    fps                  | 308        |
# |    iterations           | 24         |
# |    time_elapsed         | 159        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00968623 |
# |    clip_fraction        | 0.0993     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.72      |
# |    explained_variance   | 0.724      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.37       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0113    |
# |    std                  | 0.946      |
# |    value_loss           | 3.6        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 302          |
# | time/                   |              |
# |    fps                  | 308          |
# |    iterations           | 25           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0045680916 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.73        |
# |    explained_variance   | 0.271        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.878        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00599     |
# |    std                  | 0.946        |
# |    value_loss           | 8.34         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 309          |
# | time/                   |              |
# |    fps                  | 308          |
# |    iterations           | 26           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0054486636 |
# |    clip_fraction        | 0.0712       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.72        |
# |    explained_variance   | 0.447        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.812        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0108      |
# |    std                  | 0.938        |
# |    value_loss           | 6.6          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 311         |
# | time/                   |             |
# |    fps                  | 308         |
# |    iterations           | 27          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007734516 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.364       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.928       |
# |    value_loss           | 3.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 316         |
# | time/                   |             |
# |    fps                  | 309         |
# |    iterations           | 28          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.006571632 |
# |    clip_fraction        | 0.0565      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.76        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.009      |
# |    std                  | 0.926       |
# |    value_loss           | 7.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 319         |
# | time/                   |             |
# |    fps                  | 308         |
# |    iterations           | 29          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004926121 |
# |    clip_fraction        | 0.0523      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.1         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00703    |
# |    std                  | 0.93        |
# |    value_loss           | 9.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 319         |
# | time/                   |             |
# |    fps                  | 308         |
# |    iterations           | 30          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.006732733 |
# |    clip_fraction        | 0.0582      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.734       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.66        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00941    |
# |    std                  | 0.931       |
# |    value_loss           | 6.53        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 322          |
# | time/                   |              |
# |    fps                  | 308          |
# |    iterations           | 31           |
# |    time_elapsed         | 205          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0066784117 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.69        |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.74         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00848     |
# |    std                  | 0.921        |
# |    value_loss           | 6.19         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 322          |
# | time/                   |              |
# |    fps                  | 309          |
# |    iterations           | 32           |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0090194205 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.564        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.01         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00955     |
# |    std                  | 0.923        |
# |    value_loss           | 7.43         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 319         |
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 33          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007680376 |
# |    clip_fraction        | 0.0804      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.369       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.867       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00967    |
# |    std                  | 0.915       |
# |    value_loss           | 5.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 320         |
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 34          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008879768 |
# |    clip_fraction        | 0.0709      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.742       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0088     |
# |    std                  | 0.901       |
# |    value_loss           | 3.45        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 322          |
# | time/                   |              |
# |    fps                  | 303          |
# |    iterations           | 35           |
# |    time_elapsed         | 235          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0064123007 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.61        |
# |    explained_variance   | 0.385        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00753     |
# |    std                  | 0.886        |
# |    value_loss           | 6.53         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 324          |
# | time/                   |              |
# |    fps                  | 302          |
# |    iterations           | 36           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0078555625 |
# |    clip_fraction        | 0.0737       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.258        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00995     |
# |    std                  | 0.884        |
# |    value_loss           | 5.81         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 326          |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 37           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0076223994 |
# |    clip_fraction        | 0.0542       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.59        |
# |    explained_variance   | 0.556        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00769     |
# |    std                  | 0.883        |
# |    value_loss           | 6.43         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 331         |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 38          |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008590516 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.418       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.698       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.874       |
# |    value_loss           | 3.98        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 334         |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 39          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.007660221 |
# |    clip_fraction        | 0.0949      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.014       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.48        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00916    |
# |    std                  | 0.875       |
# |    value_loss           | 5.46        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 335        |
# | time/                   |            |
# |    fps                  | 300        |
# |    iterations           | 40         |
# |    time_elapsed         | 272        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.01052354 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.57      |
# |    explained_variance   | 0.455      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.11       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0122    |
# |    std                  | 0.876      |
# |    value_loss           | 4.36       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 338          |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 41           |
# |    time_elapsed         | 279          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0069133397 |
# |    clip_fraction        | 0.0591       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.58        |
# |    explained_variance   | 0.00967      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.925        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00583     |
# |    std                  | 0.878        |
# |    value_loss           | 5            |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 336          |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 42           |
# |    time_elapsed         | 287          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0073907343 |
# |    clip_fraction        | 0.0948       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.776        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.368        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0108      |
# |    std                  | 0.861        |
# |    value_loss           | 2.83         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 332         |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 43          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009633083 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.958       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.856       |
# |    value_loss           | 6.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 331         |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 44          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008403318 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | 0.454       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.843       |
# |    value_loss           | 7.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 331         |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 45          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007175854 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.734       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00862    |
# |    std                  | 0.844       |
# |    value_loss           | 4.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 333         |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 46          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009044128 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.648       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00846    |
# |    std                  | 0.834       |
# |    value_loss           | 4.57        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 332          |
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 47           |
# |    time_elapsed         | 321          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0075920275 |
# |    clip_fraction        | 0.0696       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.47        |
# |    explained_variance   | 0.394        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.608        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00937     |
# |    std                  | 0.831        |
# |    value_loss           | 4.84         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 335         |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 48          |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006902427 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.46       |
# |    explained_variance   | -0.0244     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00933    |
# |    std                  | 0.829       |
# |    value_loss           | 6.47        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 337         |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 49          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.009975065 |
# |    clip_fraction        | 0.0949      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.46       |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.872       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.823       |
# |    value_loss           | 3.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 336         |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 50          |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008372435 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | -0.175      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.867       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00918    |
# |    std                  | 0.813       |
# |    value_loss           | 4.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 338         |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 51          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.008774661 |
# |    clip_fraction        | 0.0849      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.41       |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.615       |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.805       |
# |    value_loss           | 3.79        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | 344          |
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 52           |
# |    time_elapsed         | 355          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0077491268 |
# |    clip_fraction        | 0.0737       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0.297        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.982        |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00893     |
# |    std                  | 0.804        |
# |    value_loss           | 5.28         |
# ------------------------------------------
# ...
# |    approx_kl            | 0.041764826 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.142       |
# |    explained_variance   | 0.327       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.611       |
# |    n_updates            | 4710        |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 0.225       |
# |    value_loss           | 4.66        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 432        |
# | time/                   |            |
# |    fps                  | 141        |
# |    iterations           | 473        |
# |    time_elapsed         | 6842       |
# |    total_timesteps      | 968704     |
# | train/                  |            |
# |    approx_kl            | 0.04283531 |
# |    clip_fraction        | 0.278      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.155      |
# |    explained_variance   | 0.261      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.529      |
# |    n_updates            | 4720       |
# |    policy_gradient_loss | -0.0195    |
# |    std                  | 0.222      |
# |    value_loss           | 5.15       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 431         |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 474         |
# |    time_elapsed         | 6848        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.058728047 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.177       |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.431       |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.0198     |
# |    std                  | 0.221       |
# |    value_loss           | 3.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 431         |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 475         |
# |    time_elapsed         | 6855        |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.033981606 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.188       |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.419       |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.22        |
# |    value_loss           | 4.11        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 430        |
# | time/                   |            |
# |    fps                  | 142        |
# |    iterations           | 476        |
# |    time_elapsed         | 6861       |
# |    total_timesteps      | 974848     |
# | train/                  |            |
# |    approx_kl            | 0.05066283 |
# |    clip_fraction        | 0.289      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.192      |
# |    explained_variance   | -0.178     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.371      |
# |    n_updates            | 4750       |
# |    policy_gradient_loss | -0.0208    |
# |    std                  | 0.219      |
# |    value_loss           | 2.75       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 431        |
# | time/                   |            |
# |    fps                  | 142        |
# |    iterations           | 477        |
# |    time_elapsed         | 6867       |
# |    total_timesteps      | 976896     |
# | train/                  |            |
# |    approx_kl            | 0.03761349 |
# |    clip_fraction        | 0.267      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.204      |
# |    explained_variance   | 0.319      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.565      |
# |    n_updates            | 4760       |
# |    policy_gradient_loss | -0.0169    |
# |    std                  | 0.218      |
# |    value_loss           | 4.79       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 426        |
# | time/                   |            |
# |    fps                  | 142        |
# |    iterations           | 478        |
# |    time_elapsed         | 6874       |
# |    total_timesteps      | 978944     |
# | train/                  |            |
# |    approx_kl            | 0.03930014 |
# |    clip_fraction        | 0.265      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.206      |
# |    explained_variance   | 0.163      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.41       |
# |    n_updates            | 4770       |
# |    policy_gradient_loss | -0.0199    |
# |    std                  | 0.218      |
# |    value_loss           | 3.8        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 426        |
# | time/                   |            |
# |    fps                  | 142        |
# |    iterations           | 479        |
# |    time_elapsed         | 6880       |
# |    total_timesteps      | 980992     |
# | train/                  |            |
# |    approx_kl            | 0.04069416 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.212      |
# |    explained_variance   | -1.18      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.442      |
# |    n_updates            | 4780       |
# |    policy_gradient_loss | -0.0153    |
# |    std                  | 0.217      |
# |    value_loss           | 3.01       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 426         |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 480         |
# |    time_elapsed         | 6887        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.044728406 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.231       |
# |    explained_variance   | -0.0151     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.393       |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.023      |
# |    std                  | 0.215       |
# |    value_loss           | 3.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 426         |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 481         |
# |    time_elapsed         | 6894        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.029171914 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.247       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.298       |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.213       |
# |    value_loss           | 4.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 428         |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 482         |
# |    time_elapsed         | 6900        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.039475117 |
# |    clip_fraction        | 0.282       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.26        |
# |    explained_variance   | -0.104      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.713       |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 0.212       |
# |    value_loss           | 4.37        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 428        |
# | time/                   |            |
# |    fps                  | 143        |
# |    iterations           | 483        |
# |    time_elapsed         | 6906       |
# |    total_timesteps      | 989184     |
# | train/                  |            |
# |    approx_kl            | 0.04110821 |
# |    clip_fraction        | 0.283      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.28       |
# |    explained_variance   | 0.474      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.519      |
# |    n_updates            | 4820       |
# |    policy_gradient_loss | -0.02      |
# |    std                  | 0.21       |
# |    value_loss           | 4.49       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 429       |
# | time/                   |           |
# |    fps                  | 143       |
# |    iterations           | 484       |
# |    time_elapsed         | 6912      |
# |    total_timesteps      | 991232    |
# | train/                  |           |
# |    approx_kl            | 0.0595923 |
# |    clip_fraction        | 0.305     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.284     |
# |    explained_variance   | 0.191     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.313     |
# |    n_updates            | 4830      |
# |    policy_gradient_loss | -0.0188   |
# |    std                  | 0.21      |
# |    value_loss           | 3.95      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 430         |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 485         |
# |    time_elapsed         | 6919        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.043604244 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.283       |
# |    explained_variance   | 0.0851      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.375       |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.21        |
# |    value_loss           | 4.69        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 431       |
# | time/                   |           |
# |    fps                  | 143       |
# |    iterations           | 486       |
# |    time_elapsed         | 6925      |
# |    total_timesteps      | 995328    |
# | train/                  |           |
# |    approx_kl            | 0.0350366 |
# |    clip_fraction        | 0.263     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.278     |
# |    explained_variance   | 0.327     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.775     |
# |    n_updates            | 4850      |
# |    policy_gradient_loss | -0.0229   |
# |    std                  | 0.212     |
# |    value_loss           | 3.97      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 429        |
# | time/                   |            |
# |    fps                  | 143        |
# |    iterations           | 487        |
# |    time_elapsed         | 6932       |
# |    total_timesteps      | 997376     |
# | train/                  |            |
# |    approx_kl            | 0.03855173 |
# |    clip_fraction        | 0.318      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.275      |
# |    explained_variance   | -0.0134    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.29       |
# |    n_updates            | 4860       |
# |    policy_gradient_loss | -0.0181    |
# |    std                  | 0.211      |
# |    value_loss           | 3.56       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 428         |
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 488         |
# |    time_elapsed         | 6938        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.051542033 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.283       |
# |    explained_variance   | 0.0852      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.24        |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.21        |
# |    value_loss           | 2.81        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 424        |
# | time/                   |            |
# |    fps                  | 144        |
# |    iterations           | 489        |
# |    time_elapsed         | 6945       |
# |    total_timesteps      | 1001472    |
# | train/                  |            |
# |    approx_kl            | 0.03356351 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.292      |
# |    explained_variance   | 0.558      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.59       |
# |    n_updates            | 4880       |
# |    policy_gradient_loss | -0.017     |
# |    std                  | 0.209      |
# |    value_loss           | 4.39       |
# ----------------------------------------
# --- TRAINING COMPLETE ---

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Use the existing log_df (full monitor) if available, otherwise fall back to log_df_modified
log_df = pd.read_csv(os.path.join(TRAIN_LOG_DIR, "monitor.csv"), skiprows=1)
series = log_df['r'] if 'log_df' in globals() else log_df_modified['r']
window = 100
mov_avg = series.rolling(window=window, min_periods=1).mean()

plt.figure(figsize=(10, 6))
plt.plot(series.values, color='lightgray', alpha=0.6, label='Episode Reward')
plt.plot(mov_avg.values, color='tab:blue', linewidth=2, label=f'{window}-episode Moving Avg')
plt.title(f'Moving Average of Episode Rewards (window={window})')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.legend()
plt.grid(True)
plt.show()

# %%
# --- Test the trained model ---
env = safety_gymnasium.make("SafetyPointGoal1-v0", render_mode="human")
env = NormalizedPaperSTLRewardWrapper(env) # Use the same wrapper for testing
TRAIN_LOG_DIR = "./ppo_safety_logs/"
model.load(f"{TRAIN_LOG_DIR}/ppo_pointgoal_stl")
obs, info = env.reset(seed=42)
terminated = truncated = False
step = 0
total_reward = 0
cumulative_cost = 0

while not (terminated or truncated):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    
    cumulative_cost += info.get('cost', 0.0)
    total_reward += reward
    
    log_msg = (
        f"Step {step:03d} | "
        f"STL Reward: {reward:6.3f} | "
        f"Total Reward: {total_reward:6.3f} | "
        f"Step Cost: {info.get('cost', 0):.1f} | "
        f"Cumulative Cost: {cumulative_cost:.1f} | "
        f"Goal Dist: {info.get('goal_dist', 0):.3f}"
    )
    
    # 5. ADDED: Log to both file and console
    logging.info(log_msg)     # Writes to 'test_run.log'
    console_logger.info(log_msg) # Writes to console
    
    # time.sleep(0.05) # Reduced sleep time for faster testing
    step += 1

env.close()
# Out:
# Step 000 | STL Reward:  0.246 | Total Reward:  0.246 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.936
# Step 001 | STL Reward:  0.246 | Total Reward:  0.492 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.936
# Step 002 | STL Reward:  0.246 | Total Reward:  0.737 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.936
# Step 003 | STL Reward:  0.245 | Total Reward:  0.983 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.937
# Step 004 | STL Reward:  0.245 | Total Reward:  1.228 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.937
# Step 005 | STL Reward:  0.245 | Total Reward:  1.473 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.937
# Step 006 | STL Reward:  0.245 | Total Reward:  1.717 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.937
# Step 007 | STL Reward:  0.244 | Total Reward:  1.962 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.937
# Step 008 | STL Reward:  0.244 | Total Reward:  2.206 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.938
# Step 009 | STL Reward:  0.245 | Total Reward:  2.451 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.938
# Step 010 | STL Reward:  0.534 | Total Reward:  2.985 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.938
# Step 011 | STL Reward:  0.537 | Total Reward:  3.523 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.937
# Step 012 | STL Reward:  0.541 | Total Reward:  4.064 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.937
# Step 013 | STL Reward:  0.546 | Total Reward:  4.610 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.936
# Step 014 | STL Reward:  0.551 | Total Reward:  5.161 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.935
# Step 015 | STL Reward:  0.556 | Total Reward:  5.717 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.933
# Step 016 | STL Reward:  0.562 | Total Reward:  6.279 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.932
# Step 017 | STL Reward:  0.568 | Total Reward:  6.848 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.929
# Step 018 | STL Reward:  0.575 | Total Reward:  7.423 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0.926
# Step 019 | STL Reward:  0.581 | Total Reward:  8.004 | Step Cost: 0.0 | Cumulative Cost: 0.0 | Goal Dist: 0